# %%
import pandas as pd
re=pd.read_csv("s1.csv")

# %%
re.tail()
# Out:
#     Unnamed: 0                                         headphones   price  \
# 35          35  Boult Audio AirBass GearPods with 32H Playtime...    ₹999
# 36          36  OnePlus Bullets Wireless Z Bass Edition Blueto...  ₹1,999
# 37          37  Aroma NB119C Carter - 36 Hours Playtime Blueto...    ₹379
# 38          38                boAt Rockerz 255F Bluetooth Headset    ₹899
# 39          39  Boult Audio AirBass Xpods TWS Earbuds with 20H...    ₹999
#
#     Rating:
# 35      3.7
# 36      4.2
# 37      4.0
# 38      4.2
# 39      3.9

# %%
re.head()
# Out:
#    Unnamed: 0                                         headphones   price  \
# 0           0  JBL Tune 230NC with Active Noise Cancellation,...  ₹5,499
# 1           1  Boult Audio AirBass Xpods TWS Earbuds with 20H...    ₹999
# 2           2  boAt Airdopes 131 with upto 15 Hours Playback,...    ₹949
# 3           3  boAt Rockerz 235v2/238 with ASAP Charge and up...    ₹849
# 4           4  OnePlus Bullets Wireless Z2 with Fast Charge, ...  ₹1,899
#
#    Rating:
# 0      4.8
# 1      3.9
# 2      4.1
# 3      4.2
# 4      4.2

# %%
re.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  40 non-null     int64
#  1   headphones  40 non-null     object
#  2   price       40 non-null     object
#  3   Rating:     40 non-null     float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 1.4+ KB

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.bar(re["price"],re["headphones"],width = 0.5)
plt.rcParams["figure.figsize"] = (2,7)
plt.figure(figsize=(3,6))
plt.show()

# %%
plt.bar(re["Rating:"],re["headphones"],width = 0.4)
plt.figure(figsize=(18,16))
plt.show()
