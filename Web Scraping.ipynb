# %%
import requests
url="https://www.flipkart.com/search?q=headphones&sid=0pm%2Cfcn&as=on&as-show=on&otracker=AS_QueryStore_OrganicAutoSuggest_1_4_na_na_na&otracker1=AS_QueryStore_OrganicAutoSuggest_1_4_na_na_na&as-pos=1&as-type=RECENT&suggestionId=headphones%7CHeadphones&requestId=bc80c6fd-67b8-4aa9-a3b8-e750fbb96421&as-backfill=on"
page=requests.get(URL)

# %%
from bs4 import BeautifulSoup

# %%
soup=BeautifulSoup(page.content,'html5lib')

# %%
result=soup.find_all(class_="s1Q9rs")
for i in range(0,len(result)):
  result[i]=result[i].text
result
# Out:
# ['boAt Airdopes 131 with upto 15 Hours Playback, 13mm Dri...',
#  'boAt Rockerz 235v2/238 with ASAP Charge and upto 8 Hour...',
#  'boAt Airdopes 131 with upto 15 Hours Playback, 13mm Dri...',
#  'Boult Audio AirBass GearPods with 32H Playtime Bluetoot...',
#  'realme Buds Wireless 2 Neo with Type-C Fast Charge & Ba...',
#  'boAt Rockerz 235v2/238 with ASAP Charge and upto 8 Hour...',
#  'boAt Rockerz 255 Pro+ with ASAP Charge and upto 40 Hour...',
#  'realme Buds 2 Wired Headset',
#  'boAt Rockerz 255F Pro with ASAP Charge and upto 10 Hour...',
#  'OnePlus Bullets Wireless Z2 with Fast Charge, 30 Hrs Ba...',
#  'Noise Buds VS102 Truly Wireless Bluetooth Headset',
#  'TECHFIRE Fire 500v2 Neckband hi-bass Wireless Bluetooth...',
#  'OnePlus Bullets Wireless Z2 Bluetooth Headset',
#  'Noise Buds VS102 Truly Wireless Bluetooth Headset',
#  'realme Buds Wireless 2 Neo with Type-C Fast Charge & Ba...',
#  'boAt Rockerz 255 Pro+ with ASAP Charge and upto 40 Hour...',
# ...

# %%
result1=soup.find_all(class_="_30jeq3")
for i in range(0,len(result)):
  result1[i]=result1[i].text
result1[:40]
# Out:
# ['₹949',
#  '₹849',
#  '₹949',
#  '₹899',
#  '₹1,199',
#  '₹849',
#  '₹1,299',
#  '₹499',
#  '₹949',
#  '₹1,899',
#  '₹899',
#  '₹379',
#  '₹1,899',
#  '₹899',
#  '₹1,199',
#  '₹1,299',
#  '₹349',
#  '₹389',
#  '₹1,299',
#  '₹1,299',
#  '₹320',
#  '₹474',
#  '₹999',
#  '₹1,399',
#  '₹325',
#  '₹999',
#  '₹1,999',
#  '₹1,999',
#  '₹379',
#  '₹999',
#  '₹379',
#  '₹449',
#  '₹1,499',
#  '₹1,299',
#  '₹349',
#  '₹399',
#  '₹549',
#  '₹1,999',
#  '₹499',
#  '₹1,599']

# %%
result2=soup.find_all(class_="_3LWZlK")
for i in range(0,len(result2)):
  result2[i]=result2[i].text
result2[:40]
# Out:
# ['4.1',
#  '4.2',
#  '4.1',
#  '3.7',
#  '4.2',
#  '4.2',
#  '4.2',
#  '4.3',
#  '4.1',
#  '4.2',
#  '4.1',
#  '4',
#  '4.2',
#  '4.1',
#  '4.2',
#  '4.2',
#  '4.3',
#  '4',
#  '4',
#  '4',
#  '3.5',
#  '3.6',
#  '4.1',
#  '3.9',
#  '3.7',
#  '4.2',
#  '4.2',
#  '4.2',
#  '4',
#  '4.1',
#  '4',
#  '4.3',
#  '3.9',
#  '4',
#  '4.3',
#  '4',
#  '4.2',
#  '4.1',
#  '4.2',
#  '4.2']

# %%
import pandas as pd 
d={"headphones":result,"price":result1[:40],"Rating:":result2[:40]}
s=pd.DataFrame(d)
s
# Out:
#                                            headphones   price Rating:
# 0   boAt Airdopes 131 with upto 15 Hours Playback,...    ₹949     4.1
# 1   boAt Rockerz 235v2/238 with ASAP Charge and up...    ₹849     4.2
# 2   boAt Airdopes 131 with upto 15 Hours Playback,...    ₹949     4.1
# 3   Boult Audio AirBass GearPods with 32H Playtime...    ₹899     3.7
# 4   realme Buds Wireless 2 Neo with Type-C Fast Ch...  ₹1,199     4.2
# 5   boAt Rockerz 235v2/238 with ASAP Charge and up...    ₹849     4.2
# 6   boAt Rockerz 255 Pro+ with ASAP Charge and upt...  ₹1,299     4.2
# 7                         realme Buds 2 Wired Headset    ₹499     4.3
# 8   boAt Rockerz 255F Pro with ASAP Charge and upt...    ₹949     4.1
# 9   OnePlus Bullets Wireless Z2 with Fast Charge, ...  ₹1,899     4.2
# 10  Noise Buds VS102 Truly Wireless Bluetooth Headset    ₹899     4.1
# 11  TECHFIRE Fire 500v2 Neckband hi-bass Wireless ...    ₹379       4
# ...

# %%
len(result)
# Out:
# 40
